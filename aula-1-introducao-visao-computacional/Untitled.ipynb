# %%
import cv2
print(cv2.__version__)

# %%
cap = cv2.VideoCapture(0)


while True:
    ret, frame = cap.read()
    
    if ret:
        cv2.imshow('Imagem original', frame) 
    
    if cv2.waitKey(1) == 13:
        break
        
cap.release()
cv2.destroyAllWindows()
